# %%
####################################################
###### Import Data : FROM PDF to Delta-Lake   ######
####################################################
#####
####################################################

# Get data From Folder
#
from datetime import datetime

#datepath="2022-02-25"
datepath=datetime.today().strftime('%Y-%m-%d')

job_dir="/home/notebookuser/notebooks/cv-ngrams-classifier/job-dir/"
pdf_daily_path =job_dir+"data/raw_pdf/dt="+datepath+"/" 
#
json_daily_path=job_dir+"data/raw_json/dt="+datepath+"/"
delta_json_structure=job_dir+"data/delta/json-cv-pdf"
#
import numpy as np
import pandas as pd
#
import io
from pdfminer.converter import TextConverter
from pdfminer.pdfinterp import PDFPageInterpreter
from pdfminer.pdfinterp import PDFResourceManager
from pdfminer.pdfpage import PDFPage
#
import json
import os
from lib.local_pdfminer.json_exporter import export_as_json
from lib.local_pdfminer.json_exporter import export_as_json_page_n
#
from lib.local_sh.functions import copy_raw_sh_to_local
from lib.local_sh.functions import copy_local_to_raw_sh
#
import os
pdf_files=[val for sublist in [[os.path.join(i[0], j) for j in i[2]] for i in os.walk(pdf_daily_path)] for val in sublist]
# Meta comment to ease selecting text
#
os.system('mkdir -p '+json_daily_path)
for i, pdf_file in enumerate(pdf_files):    
    json_path = json_daily_path+"extract-"+datepath+"-"+str(i)+".json"
    data_csv=export_as_json_page_n(pdf_file, json_path)
#
### Input File in folder :  json_daily_path
##
####
#
print("PDF Miner to JSON done !")
#
##############################Execution##########################
# Out:
# PDF Miner to JSON done !

# %%
#
### Input File in folder :  json_daily_path
#
job_dir="/home/notebookuser/notebooks/cv-ngrams-classifier/job-dir/"
#
#datepath="2022-02-25"
datepath=datetime.today().strftime('%Y-%m-%d')
#
json_daily_path=job_dir+"data/raw_json/dt="+datepath+"/"
delta_json_structure=job_dir+"data/delta/json-cv-pdf"
#
##############################Execution##########################
import findspark
findspark.init()
#
import pyspark
from pyspark.sql import functions as pfunc
from pyspark.sql import SQLContext
from pyspark.sql import Window, types
import re
import pandas as pd
import numpy as np
from pandas import DataFrame
from pyspark.sql.types import IntegerType
from pyspark.sql.types import FloatType
from pyspark.sql.functions import udf
from pyspark.sql.functions import *
from scipy.stats import kstest
from scipy import stats
#
# Start Debug!!!
import os
os.system("echo $JAVA_HOME >  spark-job.log")
#os.system("export PYSPARK_SUBMIT_ARGS='---master local[*] --packages io.delta:delta-core_2.11:0.5.0 pyspark-shell' ")
os.system("echo $PYSPARK_SUBMIT_ARGS >>  spark-job.log")
#os.system("echo 'javac -version' | xargs -0 -l -d '\\n' >> spark-job.log ")
# End Debug!!!
#
sc = pyspark.SparkContext(appName="Business_Dictionary-Ngrams_CVs-Delta")
sqlContext = SQLContext(sc)
#
# Join with Internal Curation Data in urltopredict staged folder
from pyspark.sql import functions as F
### remove viewerID
internaldata_df1=sqlContext.read.json(json_daily_path).persist(pyspark.StorageLevel.MEMORY_AND_DISK_2)
#
#
internaldata_df1.printSchema()
#
internaldata_df1.show(8)
#
df1=internaldata_df1.filter("filename IS NOT NULL").filter("pages IS NOT NULL").persist(pyspark.StorageLevel.MEMORY_AND_DISK_2)
#
#df1.show(1,0)
df1.printSchema()
##
df1.write.mode("overwrite").option("mergeSchema", "true").format("delta").save(delta_json_structure)
##
####
#
print("Data Load Done!")
#
# Out:
# root
#  |-- filename: string (nullable = true)
#  |-- pages: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- p_content: string (nullable = true)
#  |    |    |-- page_n: string (nullable = true)
#
# +--------------------+--------------------+
# |            filename|               pages|
# +--------------------+--------------------+
# |Resume Lomash Upa...|[[ Curriculum Vit...|
# +--------------------+--------------------+
#
# root
#  |-- filename: string (nullable = true)
#  |-- pages: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- p_content: string (nullable = true)
#  |    |    |-- page_n: string (nullable = true)
#
# Data Load Done!

# %%
#####################################
##############################
###### Load The Delta   ######
##############################
###
### Input delta in folder :  /data

#
job_dir="/home/notebookuser/notebooks/cv-ngrams-classifier/job-dir/"
#
#datepath="2022-02-25"
datepath=datetime.today().strftime('%Y-%m-%d')
#
my_input_delta_table=job_dir+"data/delta/json-cv-pdf"
delta_ngram_structure=job_dir+"data/delta/cv-files-ngrams"
###
######
##############################Execution##########################
import findspark
findspark.init()
#
import pyspark
from pyspark.sql import functions as pfunc
from pyspark.sql import SQLContext
from pyspark.sql import Window, types
import re
import pandas as pd
import numpy as np
from pandas import DataFrame
from pyspark.sql.types import IntegerType
from pyspark.sql.types import FloatType
from pyspark.sql.functions import udf
from pyspark.sql.functions import *
from scipy.stats import kstest
from scipy import stats
#
# Join with Internal Curation Data in urltopredict staged folder
from pyspark.sql import functions as F
### use version=1
version=1
## .option("versionAsOf", version)
delta_dataframe_df1=sqlContext.read.format("delta").load(my_input_delta_table)\
.persist(pyspark.StorageLevel.MEMORY_AND_DISK_2)
#
#
delta_dataframe_df1.printSchema()
delta_dataframe_df1.registerTempTable("delta_pdf_cv")
#
#### Expose most frequent CV Terms as NGram_n - Group of [1-6] words in CV
######
####
######
from pyspark.ml.feature import NGram, CountVectorizer, VectorAssembler, RegexTokenizer
from pyspark.ml import Pipeline

def build_ngrams(inputCol="pagei", n=6):

    ngrams = [
        NGram(n=i, inputCol="pagei", outputCol="{0}_grams".format(i))
        for i in range(1, n + 1)
    ]

    vectorizers = [
        CountVectorizer(inputCol="{0}_grams".format(i),
            outputCol="{0}_counts".format(i))
        for i in range(1, n + 1)
    ]

    assembler = [VectorAssembler(
        inputCols=["{0}_counts".format(i) for i in range(1, n + 1)],
        outputCol="features"
    )]

    return Pipeline(stages=ngrams + vectorizers + assembler)

regexTokenizer = RegexTokenizer(minTokenLength=1, gaps=False, pattern='\\w+|', inputCol="pagei", outputCol="words", toLowercase=True)

#######################################

#
pages_grouped=sqlContext.sql("select * from delta_pdf_cv where 1=1 limit 10 ") #" where filename IS NOT NULL ")

pages_grouped2=pages_grouped.select(col('filename'),explode("pages.p_content").alias("pagei"))\
.select(col('filename'),explode(split(col("pagei"), "\s+[1-99]\' \'s+")).alias("pagei")) 
##[1-99]\' \'s+[1-99]\' \'s+[1-99]\' \'s+[1-99]\' \'s+[1-99]\' \'s+[1-99]\' \'s+[1-99]\' \'s+[1-99]\' \'s+[1-99]\' \'s+[1-99]\' \'s+[1-99]\' \'s+
pages_grouped2.printSchema()

tokenized_DF = regexTokenizer.transform(pages_grouped2).select(col('Filename'),col("words").alias("pagei")).filter("pagei IS NOT NULL ")

tokenized_DF.printSchema()
tokenized_DF.show(5,0)

NgramDF = build_ngrams().fit(tokenized_DF).transform(tokenized_DF)
NgramDF.printSchema()
NgramDF.write.mode("overwrite").option("mergeSchema", "true").format("delta").save(delta_ngram_structure)
#
Ngram6DF=NgramDF.groupBy("6_grams").count().orderBy(col('count').desc())      
Ngram6DF.show(10,0)
#
Ngram5DF=NgramDF.groupBy("5_grams").count().orderBy(col('count').desc())      
Ngram5DF.show(10,0)
#
Ngram4DF=NgramDF.groupBy("4_grams").count().orderBy(col('count').desc())      
Ngram4DF.show(10,0)
#
Ngram3DF=NgramDF.groupBy("3_grams").count().orderBy(col('count').desc())      
Ngram3DF.show(10,0)
#
Ngram2DF=NgramDF.groupBy("2_grams").count().orderBy(col('count').desc())      
Ngram2DF.show(10,0)
#
Ngram1DF=NgramDF.groupBy("1_grams").count().orderBy(col('count').desc())      
Ngram1DF.show(10,0)
#
print("Load Ngrams to Delta Done")
print("Calculate top 10 most frequent 1,2,3,4,5,6 ngrams  - Finished!")
#
sc.stop()
#
# Out:
# root
#  |-- filename: string (nullable = true)
#  |-- pages: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- p_content: string (nullable = true)
#  |    |    |-- page_n: string (nullable = true)
#
# root
#  |-- filename: string (nullable = true)
#  |-- pagei: string (nullable = true)
#
# root
#  |-- Filename: string (nullable = true)
#  |-- pagei: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#
# +---------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |Filename                   |pagei                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |
# +---------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |Resume Lomash Upadhyay-2022|[curriculum, vitae, email, lomash, upadhyay, gmail, com, phone, 1, 647, 937, 3402, lomash, upadhyay, profile, 19, years, of, it, service, consulting, experience, in, technology, software, delivery, and, technical, architecture, with, significant, depth, in, the, airline, credit, cards, insurance, and, mobile, payment, domains, experience, working, multi, cultural, environments, across, india, middle, east, north, america, europe, and, apac, key, skills, 8, years, of, api, design, development, experience, using, event, storming, approach, in, canadian, banks, 7, years, of, api, governance, experience, in, canadian, banks, and, insurance, provider, 4, years, of, event, driven, architecture, design, and, implementation, 4, years, of, micro, services, design, and, development, 3, years, of, dev, ops, automation, experience, in, canadian, bank, java, java, ee, design, and, development, experience, experience, in, platform, modernization, projects, cloud, enablement, micro, services, event, driven, systems, experience, in, software, technology, evaluation, design, patterns, software, design, architecture, experience, in, client, presentations, technical, support, and, training, technical, languages, java, node, js, basic, unix, scripting, databases, oracle, mysql, mongo, db, version, control, systems, svn, git, perforce, cloud, source, repository, products, frameworks, spring, spring, boot, api, gateway, apigee, zuul, swagger, raml, terraform, kafka, kafka, connect, change, data, capture, solutions, attunity, replicate, cloud, providers, gcp, aws, other, tools, technologies, docker, kubernetes, open, shift, jenkins, cdd, broadcom, apm, apm, qualifications, google, cloud, certified, professional, cloud, architect, 2018, 2020, https, www, credential, net, 3tchs4fb, key, ce2559f7fcbbf6fadc842414216cf7a6ed04033b5814a3df353612b6ffb113ab, node, js, certified, developer, 2015, ibm, uml, design, certification, 2007]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |
# |Resume Lomash Upadhyay-2022|[lomash, upadhyay, 2, 4, masters, in, computer, applications, 2001]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      |
# |Resume Lomash Upadhyay-2022|[lomash, upadhyay, 2, 4, experience, sunlife, financial, inc, director, api, platform, engineering, aug, 2020, present, api, platform, engineering, sunlife, involved, in, end, to, end, implementation, and, operationalization, of, sunlife, api, platform, involved, in, establishing, api, design, standards, rollout, for, the, global, api, platform, to, multiple, regions, in, sunlife, involve, in, the, end, to, end, implementation, of, internal, api, marketplace, and, partner, api, marketplace, involved, in, aws, serverless, pattern, roll, out, for, implementing, api, s, enterprise, event, hub, platform, engineering, sunlife, involved, in, end, to, end, implementation, and, operationalization, of, sunlife, enterprise, event, platform, multi, region, confluent, kafka, 6, 2, x, involved, in, end, to, end, implementation, and, operationalization, of, change, data, capture, to, move, data, from, multiple, data, sources, into, kafka, involved, in, operations, setup, for, the, event, hub, capability, other, activities, platform, evangelization, among, sunlife, delivery, teams, using, technical, advisory, group, session, and, api, guild, sessions, provided, technical, trainings, in, sunlife, for, api, development, api, design, microservices, framework, api, access, management, involved, in, executive, demos, of, platform, capabilities, across, regions, in, sunlife, gft, canada, senior, cloud, architect, oct, 2017, aug, 2020, api, microservices, sme, sunlife, working, with, api, team, at, sun, life, closely, involved, in, api, strategy, and, implementation, working, on, build, of, digital, decoupling, micro, services, at, services, completed, the, oauth, proof, of, concept, on, software, ag, gateway, experience, with, micro, service, frameworks, light, 4, j, google, gcp, sme, connected, car, gcp, infrastructure, design, and, provisioning, using, terraform, performance, testing, of, the, end, to, end, connected, car, solution, built, on, gcp, services, key, gcp, components, worked, on, in, this, project, o, iot, core, o, data, flow, o, big, query, o, cloud, functions, o, app, engine, o, firebase, o, cloud, data, studio, canadian, bank, senior, api, sme, plato, platform, modernization]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       |
# |Resume Lomash Upadhyay-2022|[lomash, upadhyay, 2, 4, set, up, api, design, and, governance, process, plan, and, create, enterprise, baas, api, s, for, multiple, regions, of, the, bank, participated, in, google, cloud, innovation, proof, of, concept, for, the, bank, isitio, services, integration, of, services, with, apigee, kubernetes, cluster, setup, designed, and, implemented, micro, services, using, spring, boot, setup, of, kafka, clusters, on, google, cloud, platform, google, data, engineering, workshop, new, york, april, 18, hands, on, workshop, at, google, office, introducing, partners, to, the, data, engineering, solutions, like, google, big, query, big, table, data, flow, and, ml, on, google, cloud, platform, uk, insurance, provider, aws, solution, architect, rate, quote, bind, system, jan, to, feb, 18, project, involved, migrating, client, legacy, insurance, application, to, aws, cloud, amazon, vpc, design, and, implementation, application, design, and, implementation, using, lambda, functions, automating, build, and, deployment, of, the, application, to, amazon, tools, like, code, commit, code, build, and, cloud, formation, sapient, architect, oct, 2011, to, oct, 2017, api, governance, design, and, implementation, tier1, canadian, bank, march, 2016, to, oct, 2017, design, and, development, policy, enforcement, point, api, for, the, bank, which, involved, design, and, implementation, of, services, connected, to, local, data, stores, data, changes, from, legacy, database, captures, using, kafka, connect, involved, in, setting, up, kafka, clusters, on, td, private, cloud, api, consultant, for, the, development, design, devops, deployment, of, 50, apis, using, java, node, across, the, lines, of, businesses, api, coach, for, back, end, api, developed, across, all, lines, of, business, while, enforcing, a, single, unified, enterprise, data, model, individual, contributor, for, multiple, api, developments, completely, also, contributed, through, code, configurations, based, on, the, requirements, in, the, teams, as, and, when, required, throughout, the, tenure, of, the, consulting, coaching, delivered, functional, specification, traceable, to, brd, and, test, cases, contributor, towards, node, java, api, framework, and, its, adoption, through, code, examples, archetypes, documentation, participating, in, internal, intake, and, pre, sales, discussions, mobile, wallet, implementations, tier, 1, canadian, bank, may, 2013, to, march, 2016]                                                                                                                                                                                                                                                                                                                                                                                                                                    |
# |Resume Lomash Upadhyay-2022|[lomash, upadhyay, 2, 4, involved, in, ugo, mobile, wallet, which, allow, customers, to, use, their, mobile, device, to, complete, mastercard, or, visa, transactions, as, well, as, access, their, pc, plus, tm, account, to, earn, and, redeem, pc, points, involved, in, canadian, bank, mobile, wallet, initiative, involves, collaboration, with, mobile, network, operators, and, trusted, service, manager, to, securely, place, customers, payment, credentials, on, their, mobile, sim, card, the, uicc, this, solution, takes, advantage, of, the, existing, capabilities, of, the, canadian, ecosystem, managing, the, onshore, activities, of, the, project, issues, resolution, help, the, teams, resolve, technical, issues, and, provide, suggestion, to, tackle, the, same, co, ordination, with, offshore, team, client, interactions, with, respect, to, status, reporting, discussions, on, critical, defects, and, change, controls, mbna, sales, application, tier1, canadian, bank, nov, 2011, to, may, 2013, involved, in, building, system, to, enable, creation, of, credit, card, sales, applications, for, mbna, using, the, campaign, management, tool, and, presentment, to, customer, for, sales, fulfilment, managing, the, offshore, activities, of, the, project, task, allocation, to, the, team, members, issues, resolution, help, the, teams, resolve, technical, issues, and, provide, suggestion, to, tackle, the, same, quality, control, ensuring, that, the, quality, processes, are, adhered, to, co, ordination, with, onshore, team, client, interactions, with, respect, to, status, reporting, discussions, on, critical, defects, and, change, controls, infogain, india, p, ltd, associate, consultant, may, 2010, to, oct, 2013, automotive, insurance, product, suite, the, project, involved, creation, of, a, suite, of, automobile, insurance, products, for, progressive, a, leading, us, automotive, insurance, provider, involved, in, effort, estimation, activities, involved, in, resource, planning, and, work, allocations, to, team, involved, in, high, level, low, level, design, preparation, and, reviews, involved, in, coding, activities, doing, poc, to, find, solutions, to, technical, issues, steria, technical, lead, nov, 2006, to, may, 2010, experience, in, multiple, development, and, support, projects, for, banking, and, financial, services, client, uk, involved, in, high, level, low, level, design, preparation, and, reviews, involved, in, coding, activities, doing, poc, to, find, solutions, to, technical, issues, mind, tree, technical, lead, sept, 2004, to, nov, 2006, experience, in, multiple, development, and, support, projects, for, emirates, airlines, it, was, really, ambitious, initiative, taken, up, by, our, client, emirates, airlines, to, make, the, entire, process, of, managing, and, controlling, cargo, distribution, across, the, emirates, network, automated]|
# +---------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 5 rows
# root
#  |-- Filename: string (nullable = true)
#  |-- pagei: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- 1_grams: array (nullable = true)
#  |    |-- element: string (containsNull = false)
#  |-- 2_grams: array (nullable = true)
#  |    |-- element: string (containsNull = false)
#  |-- 3_grams: array (nullable = true)
#  |    |-- element: string (containsNull = false)
#  |-- 4_grams: array (nullable = true)
#  |    |-- element: string (containsNull = false)
#  |-- 5_grams: array (nullable = true)
#  |    |-- element: string (containsNull = false)
#  |-- 6_grams: array (nullable = true)
#  |    |-- element: string (containsNull = false)
#  |-- 1_counts: vector (nullable = true)
#  |-- 2_counts: vector (nullable = true)
#  |-- 3_counts: vector (nullable = true)
#  |-- 4_counts: vector (nullable = true)
#  |-- 5_counts: vector (nullable = true)
#  |-- 6_counts: vector (nullable = true)
#  |-- features: vector (nullable = true)
#
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# |6_grams                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         ...
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# |[curriculum vitae email lomash upadhyay gmail, vitae email lomash upadhyay gmail com, email lomash upadhyay gmail com phone, lomash upadhyay gmail com phone 1, upadhyay gmail com phone 1 647, gmail com phone 1 647 937, com phone 1 647 937 3402, phone 1 647 937 3402 lomash, 1 647 937 3402 lomash upadhyay, 647 937 3402 lomash upadhyay profile, 937 3402 lomash upadhyay profile 19, 3402 lomash upadhyay profile 19 years, lomash upadhyay profile 19 years of, upadhyay profile 19 years of it, profile 19 years of it service, 19 years of it service consulting, years of it service consulting experience, of it service consulting experience in, it service consulting experience in technology, service consulting experience in technology software, consulting experience in technology software delivery, experience in technology software delivery and, in technology software delivery and technical, technology software delivery and technical architecture, software delivery and technical architecture with, delivery and technical architecture with significant, and technical architecture with significant depth, technical architecture with significant depth in, architecture with significant depth in the, with significant depth in the airline, significant depth in the airline credit, depth in the airline credit cards, in the airline credit cards insurance, the airline credit cards insurance and, airline credit cards insurance and mobile, credit cards insurance and mobile payment, cards insurance and mobile payment domains, insurance and mobile payment domains experience, and mobile payment domains experience working, mobile payment domains experience working multi, payment domains experience working multi cultural, domains experience working multi cultural environments, experience working multi cultural environments across, working multi cultural environments across india, multi cultural environments across india middle, cultural environments across india middle east, environments across india middle east north, across india middle east north america, india middle east north america europe, middle east north america europe and, east north america europe and apac, north america europe and apac key, america europe and apac key skills, europe and apac key skills 8, and apac key skills 8 years, apac key skills 8 years of, key skills 8 years of api, skills 8 years of api design, 8 years of api design development, years of api design development experience, of api design development experience using, api design development experience using event, design development experience using event storming, development experience using event storming approach, experience using event storming approach in, using event storming approach in canadian, event storming approach in canadian banks, storming approach in canadian banks 7, approach in canadian banks 7 years, in canadian banks 7 years of, canadian banks 7 years of api, banks 7 years of api governance, 7 years of api governance experience, years of api governance experience in, of api governance experience in canadian, api governance experience in canadian banks, governance experience in canadian banks and, experience in canadian banks and insurance, in canadian banks and insurance provider, canadian banks and insurance provider 4, banks and insurance provider 4 years, and insurance provider 4 years of, insurance provider 4 years of event, provider 4 years of event driven, 4 years of event driven architecture, years of event driven architecture design, of event driven architecture design and, event driven architecture design and implementation, driven architecture design and implementation 4, architecture design and implementation 4 years, design and implementation 4 years of, and implementation 4 years of micro, implementation 4 years of micro services, 4 years of micro services design, years of micro services design and, of micro services design and development, micro services design and development 3, services d ...
# |[lomash upadhyay 2 4 masters in, upadhyay 2 4 masters in computer, 2 4 masters in computer applications, 4 masters in computer applications 2001]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...
# ...
# |[lomash, upadhyay, 2, 4, experience, sunlife, financial, inc, director, api, platform, engineering, aug, 2020, present, api, platform, engineering, sunlife, involved, in, end, to, end, implementation, and, operationalization, of, sunlife, api, platform, involved, in, establishing, api, design, standards, rollout, for, the, global, api, platform, to, multiple, regions, in, sunlife, involve, in, the, end, to, end, implementation, of, internal, api, marketplace, and, partner, api, marketplace, involved, in, aws, serverless, pattern, roll, out, for, implementing, api, s, enterprise, event, hub, platform, engineering, sunlife, involved, in, end, to, end, implementation, and, operationalization, of, sunlife, enterprise, event, platform, multi, region, confluent, kafka, 6, 2, x, involved, in, end, to, end, implementation, and, operationalization, of, change, data, capture, to, move, data, from, multiple, data, sources, into, kafka, involved, in, operations, setup, for, the, event, hub, capability, other, activities, platform, evangelization, among, sunlife, delivery, teams, using, technical, advisory, group, session, and, api, guild, sessions, provided, technical, trainings, in, sunlife, for, api, development, api, design, microservices, framework, api, access, management, involved, in, executive, demos, of, platform, capabilities, across, regions, in, sunlife, gft, canada, senior, cloud, architect, oct, 2017, aug, 2020, api, microservices, sme, sunlife, working, with, api, team, at, sun, life, closely, involved, in, api, strategy, and, implementation, working, on, build, of, digital, decoupling, micro, services, at, services, completed, the, oauth, proof, of, concept, on, software, ag, gateway, experience, with, micro, service, frameworks, light, 4, j, google, gcp, sme, connected, car, gcp, infrastructure, design, and, provisioning, using, terraform, performance, testing, of, the, end, to, end, connected, car, solution, built, on, gcp, services, key, gcp, components, worked, on, in, this, project, o, iot, core, o, data, flow, o, big, query, o, cloud, functions, o, app, engine, o, firebase, o, cloud, data, studio, canadian, bank, senior, api, sme, plato, platform, modernization]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       |1    |
# |[lomash, upadhyay, 2, 4, set, up, api, design, and, governance, process, plan, and, create, enterprise, baas, api, s, for, multiple, regions, of, the, bank, participated, in, google, cloud, innovation, proof, of, concept, for, the, bank, isitio, services, integration, of, services, with, apigee, kubernetes, cluster, setup, designed, and, implemented, micro, services, using, spring, boot, setup, of, kafka, clusters, on, google, cloud, platform, google, data, engineering, workshop, new, york, april, 18, hands, on, workshop, at, google, office, introducing, partners, to, the, data, engineering, solutions, like, google, big, query, big, table, data, flow, and, ml, on, google, cloud, platform, uk, insurance, provider, aws, solution, architect, rate, quote, bind, system, jan, to, feb, 18, project, involved, migrating, client, legacy, insurance, application, to, aws, cloud, amazon, vpc, design, and, implementation, application, design, and, implementation, using, lambda, functions, automating, build, and, deployment, of, the, application, to, amazon, tools, like, code, commit, code, build, and, cloud, formation, sapient, architect, oct, 2011, to, oct, 2017, api, governance, design, and, implementation, tier1, canadian, bank, march, 2016, to, oct, 2017, design, and, development, policy, enforcement, point, api, for, the, bank, which, involved, design, and, implementation, of, services, connected, to, local, data, stores, data, changes, from, legacy, database, captures, using, kafka, connect, involved, in, setting, up, kafka, clusters, on, td, private, cloud, api, consultant, for, the, development, design, devops, deployment, of, 50, apis, using, java, node, across, the, lines, of, businesses, api, coach, for, back, end, api, developed, across, all, lines, of, business, while, enforcing, a, single, unified, enterprise, data, model, individual, contributor, for, multiple, api, developments, completely, also, contributed, through, code, configurations, based, on, the, requirements, in, the, teams, as, and, when, required, throughout, the, tenure, of, the, consulting, coaching, delivered, functional, specification, traceable, to, brd, and, test, cases, contributor, towards, node, java, api, framework, and, its, adoption, through, code, examples, archetypes, documentation, participating, in, internal, intake, and, pre, sales, discussions, mobile, wallet, implementations, tier, 1, canadian, bank, may, 2013, to, march, 2016]                                                                                                                                                                                                                                                                                                                                                                                                                                    |1    |
# |[lomash, upadhyay, 2, 4, involved, in, ugo, mobile, wallet, which, allow, customers, to, use, their, mobile, device, to, complete, mastercard, or, visa, transactions, as, well, as, access, their, pc, plus, tm, account, to, earn, and, redeem, pc, points, involved, in, canadian, bank, mobile, wallet, initiative, involves, collaboration, with, mobile, network, operators, and, trusted, service, manager, to, securely, place, customers, payment, credentials, on, their, mobile, sim, card, the, uicc, this, solution, takes, advantage, of, the, existing, capabilities, of, the, canadian, ecosystem, managing, the, onshore, activities, of, the, project, issues, resolution, help, the, teams, resolve, technical, issues, and, provide, suggestion, to, tackle, the, same, co, ordination, with, offshore, team, client, interactions, with, respect, to, status, reporting, discussions, on, critical, defects, and, change, controls, mbna, sales, application, tier1, canadian, bank, nov, 2011, to, may, 2013, involved, in, building, system, to, enable, creation, of, credit, card, sales, applications, for, mbna, using, the, campaign, management, tool, and, presentment, to, customer, for, sales, fulfilment, managing, the, offshore, activities, of, the, project, task, allocation, to, the, team, members, issues, resolution, help, the, teams, resolve, technical, issues, and, provide, suggestion, to, tackle, the, same, quality, control, ensuring, that, the, quality, processes, are, adhered, to, co, ordination, with, onshore, team, client, interactions, with, respect, to, status, reporting, discussions, on, critical, defects, and, change, controls, infogain, india, p, ltd, associate, consultant, may, 2010, to, oct, 2013, automotive, insurance, product, suite, the, project, involved, creation, of, a, suite, of, automobile, insurance, products, for, progressive, a, leading, us, automotive, insurance, provider, involved, in, effort, estimation, activities, involved, in, resource, planning, and, work, allocations, to, team, involved, in, high, level, low, level, design, preparation, and, reviews, involved, in, coding, activities, doing, poc, to, find, solutions, to, technical, issues, steria, technical, lead, nov, 2006, to, may, 2010, experience, in, multiple, development, and, support, projects, for, banking, and, financial, services, client, uk, involved, in, high, level, low, level, design, preparation, and, reviews, involved, in, coding, activities, doing, poc, to, find, solutions, to, technical, issues, mind, tree, technical, lead, sept, 2004, to, nov, 2006, experience, in, multiple, development, and, support, projects, for, emirates, airlines, it, was, really, ambitious, initiative, taken, up, by, our, client, emirates, airlines, to, make, the, entire, process, of, managing, and, controlling, cargo, distribution, across, the, emirates, network, automated]|1    |
# |[lomash, upadhyay, 2, 4, requirement, gathering, sessions, with, business, teams, involved, in, high, level, low, level, design, preparation, and, reviews, involved, in, coding, activities, doing, poc, to, find, solutions, to, technical, issues, wipro, technologies, system, engineer, may, 2002, to, aug, 2004, web, administration, tool, the, project, was, to, develop, a, web, administration, tool, for, the, mco, product, development, of, the, module, unit, testing, integration, testing]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               |1    |
# +-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----+
#
# Load Ngrams to Delta Done
# Calculate top 10 most frequent 1,2,3,4,5,6 ngrams  - Finished!

# %%
sc.stop()

# %%
#######################################################
###### Import Skills Data : FROM CSV to Delta-Lake ####
#######################################################
#####
####################################################
#
job_dir="/home/notebookuser/notebooks/cv-ngrams-classifier/job-dir/"
#
skills_bulk_path=job_dir+"data/raw_role_skills/*.csv"
#
delta_skills_structure=job_dir+"data/delta/role_skills"
#
##############################Execution##########################
import findspark
findspark.init()
#
import pyspark
from pyspark.sql import functions as pfunc
from pyspark.sql import SQLContext
from pyspark.sql import Window, types
import re
import pandas as pd
import numpy as np
from pandas import DataFrame
from pyspark.sql.types import IntegerType
from pyspark.sql.types import FloatType
from pyspark.sql.functions import udf
from pyspark.sql.functions import *
from scipy.stats import kstest
from scipy import stats
#
# Join with Internal Curation Data in urltopredict staged folder
from pyspark.sql import functions as F
#
sc = pyspark.SparkContext(appName="Role_Skills_Dictionary-Ngrams_CVs-Delta")
sqlContext = SQLContext(sc)
### remove viewerID
internaldata_df1=sqlContext.read.csv(skills_bulk_path,header='true').persist(pyspark.StorageLevel.MEMORY_AND_DISK_2)
#
#
internaldata_df1.printSchema()
#
internaldata_df1.show(8)
#
df1=internaldata_df1.filter("skill IS NOT NULL").filter("role IS NOT NULL").persist(pyspark.StorageLevel.MEMORY_AND_DISK_2)
#
df1.show(1,0)
##
df1.write.mode("overwrite").option("mergeSchema", "true").format("delta").save(delta_skills_structure)
##
print("Skills Load Done!")
#
#####################################
####
sc.stop()
#
print("All Loading Jobs Done!")
#######
# Out:
# root
#  |-- skill: string (nullable = true)
#  |-- role: string (nullable = true)
#  |-- level: string (nullable = true)
#
# +------+-------------+-----+
# | skill|         role|level|
# +------+-------------+-----+
# |python|data engineer|    2|
# |python|data engineer|    3|
# |python|data engineer|    4|
# |python|data engineer|    5|
# | scala|data engineer|    3|
# | scala|data engineer|    4|
# | scala|data engineer|    5|
# |  java|data engineer|    2|
# +------+-------------+-----+
# only showing top 8 rows
#
# +------+-------------+-----+
# |skill |role         |level|
# +------+-------------+-----+
# |python|data engineer|2    |
# +------+-------------+-----+
# only showing top 1 row

# %%
sc.stop()
